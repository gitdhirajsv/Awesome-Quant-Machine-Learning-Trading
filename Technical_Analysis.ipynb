# %% [markdown]
# <a href="https://colab.research.google.com/github/gitdhirajsv/Awesome-Quant-Machine-Learning-Trading/blob/master/Technical_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  requests numpy pandas matplotlib mpld3 requests pandas numpy plotly scipy beautifulsoup4 binance-futures technical python-bingx -U kaleido pynescript

# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib
import talib
import pandas as pd
from bingX.perpetual.v2 import PerpetualV2
import requests
import time
import hashlib
import hmac
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# ...
#   Using cached matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# ...
#   Using cached mpld3-0.5.10-py3-none-any.whl (202 kB)
# ...
#   Using cached plotly-5.22.0-py3-none-any.whl (16.4 MB)
# ...
#   Using cached scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# ...
#   Using cached binance_futures-0.0.1-py3-none-any.whl (99 kB)
# ...
#   Using cached technical-1.4.3-py3-none-any.whl (50 kB)
# ...
#   Using cached python_bingx-1.0.0-py3-none-any.whl (19 kB)
# ...
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# ...
#   Using cached pynescript-0.2.0-py3-none-any.whl (116 kB)
# ...
#   Using cached APScheduler-3.10.4-py3-none-any.whl (59 kB)
# ...

# %% [markdown]
# # API Details

# %%
import time
import requests
import hmac
from hashlib import sha256

APIURL = "https://open-api.bingx.com"
API_KEY = 'Yqq0iIgNBf42XovZDMJZngwP9Mnd2Y87j3FatFM3x4DV4sYb9Lt3mPpxLaAQJQRztEeySt8xe4NuiCRJMg'
SECRET_KEY = 'sStMj2qqC5i7rWurjTKmgmFmCBO1UUcf3CTmloE5NhWdbhPXCLnoSmmRq65qdAD5UuSjM0mukh8ivQ'

def get_sign(api_secret, payload):
    signature = hmac.new(api_secret.encode("utf-8"), payload.encode("utf-8"), digestmod=sha256).hexdigest()
    return signature

def send_request(method, path, urlpa, payload):
    url = f"{APIURL}{path}?{urlpa}&signature={get_sign(SECRETKEY, urlpa)}"
    headers = {
        'X-BX-APIKEY': APIKEY,
    }
    response = requests.request(method, url, headers=headers, data=payload)
    return response.text

def parse_param(paramsMap):
    sortedKeys = sorted(paramsMap)
    paramsStr = "&".join([f"{x}={paramsMap[x]}" for x in sortedKeys])
    if paramsStr != "":
        return f"{paramsStr}&timestamp={int(time.time() * 1000)}"
    else:
        return f"{paramsStr}timestamp={int(time.time() * 1000)}"

def get_api_data(endpoint, paramsMap):
    method = "GET"
    path = f"/openApi/{endpoint}"
    paramsStr = parse_param(paramsMap)
    return send_request(method, path, paramsStr, {})

# Define API endpoints and sample parameters
api_endpoints = {
    "swap_v2_quote_contracts": {
        "path": "/swap/v2/quote/contracts",
        "params": {}
    },
    "swap_v2_quote_depth": {
        "path": "/swap/v2/quote/depth",
        "params": {"symbol": "SHIB-USDT", "limit": 5}
    },
    "swap_v2_quote_trades": {
        "path": "/swap/v2/quote/trades",
        "params": {"symbol": "BTC-USDT", "limit": 10}
    },
    "swap_v2_quote_premiumIndex": {
        "path": "/swap/v2/quote/premiumIndex",
        "params": {"symbol": "BTC-USDT"}
    },
    "swap_v2_quote_fundingRate": {
        "path": "/swap/v2/quote/fundingRate",
        "params": {"symbol": "QNT-USDT", "limit": 2}
    },
    "swap_v3_quote_klines": {
        "path": "/swap/v3/quote/klines",
        "params": {"symbol": "KNC-USDT", "interval": "1h", "limit": 1000, "startTime": 1702717199998}
    },
    "swap_v2_quote_openInterest": {
        "path": "/swap/v2/quote/openInterest",
        "params": {"symbol": "EOS-USDT"}
    },
    "swap_v2_quote_ticker": {
        "path": "/swap/v2/quote/ticker",
        "params": {"symbol": "SFP-USDT", "timestamp": 1702719836770}
    },
    "swap_v1_market_historicalTrades": {
        "path": "/swap/v1/market/historicalTrades",
        "params": {"fromId": 412551, "limit": 500, "symbol": "ETH-USDT", "timestamp": 1702731995838, "recvWindow": 60000}
    },
    "swap_v2_quote_bookTicker": {
        "path": "/swap/v2/quote/bookTicker",
        "params": {"symbol": "BTC-USDT", "timestamp": 1702719942130}
    },
    "swap_v1_market_markPriceKlines": {
        "path": "/swap/v1/market/markPriceKlines",
        "params": {"symbol": "KNC-USDT", "interval": "1h", "limit": 1000, "startTime": 1702717199998}
    },
    "swap_v1_ticker_price": {
        "path": "/swap/v1/ticker/price",
        "params": {"symbol": "BTC-USDT"}
    }
}

# Fetch API data for each endpoint
api_data = {}
for endpoint, data in api_endpoints.items():
    path = data["path"]
    params = data["params"]
    api_data[endpoint] = get_api_data(path[1:], params)

# Print the API data for each endpoint
for endpoint, data in api_data.items():
    print(f"Endpoint: {endpoint}")
    print(data)
    print("-------------------------------")

# %% [markdown]
# #Symbol Pairs

# %%
symbol_pairs = ['10000000-AIDOGE-USDT', '10000-LADY-USDT', '10000-SATS-USDT', '1000-BONK-USDT', '1000-PEPE-USDT', '1INCH-USDT', 'AAVE-USDT', 'ACE-USDT', 'ACH-USDT', 'ADA-USDT', 'AEVO-USDT', 'AGIX-USDT', 'AGLD-USDT', 'ALGO-USDT', 'ALT-USDT', 'AMB-USDT', 'ANKR-USDT', 'APE-USDT', 'API3-USDT', 'APT-USDT', 'ARB-USDT', 'ARK-USDT', 'ARPA-USDT', 'ASTR-USDT', 'ATA-USDT', 'ATOM-USDT', 'AUCTION-USDT', 'AVAX-USDT', 'AXS-USDT', 'BADGER-USDT', 'BAKE-USDT', 'BAT-USDT', 'BB-USDT', 'BCH-USDT', 'BEAM-USDT', 'BIGTIME-USDT', 'BLUR-USDT', 'BLZ-USDT', 'BNB-USDT', 'BNT-USDT', 'BNX-USDT', 'BOME-USDT', 'BOND-USDT', 'BSV-USDT', 'BTC-USDT', 'CAKE-USDT', 'CELO-USDT', 'CELR-USDT', 'CFX-USDT', 'CHR-USDT', 'CHZ-USDT', 'CKB-USDT', 'COMBO-USDT', 'COMP-USDT', 'CORE-USDT', 'COTI-USDT', 'CRV-USDT', 'CTC-USDT', 'CYBER-USDT', 'DAR-USDT', 'DEGEN-USDT', 'DOGE-USDT', 'DOT-USDT', 'DUSK-USDT', 'DYDX-USDT', 'DYM-USDT', 'EDU-USDT', 'EGLD-USDT', 'ENA-USDT', 'ENJ-USDT', 'ENS-USDT', 
USDT', 'UNFI-USDT', 'UNI-USDT', 'UST-USDT', 'VANRY-USDT', 'VET-USDT', 'VGX-USDT', 'WAVES-USDT', 'WAXP-USDT', 'WIF-USDT', 'WLD-USDT', 'WOO-USDT', 'W-USDT', 'XAI-USDT', 'XLM-USDT', 'XRP-USDT', 'YFI-USDT', 'YGG-USDT', 'ZEROLEND-USDT', 'ZETA-USDT', 'ZEUS-USDT', 'ZIL-USDT', 'ZRX-USDT']

# %% [markdown]
# # Falling Wedge Pattern

# %%
import requests

def get_indicator_values(symbol, interval, limit):
    url = "https://open-api.bingx.com/openApi/spot/v2/market/kline"
    params = {
        'symbol': symbol,
        'interval': interval,
        'limit': limit
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        if 'data' in data and isinstance(data['data'], list):
            klines = data['data']
            if len(klines) >= limit:
                high_prices = [float(kline[2]) for kline in klines]
                low_prices = [float(kline[3]) for kline in klines]
                return high_prices, low_prices
    return [], []

def filter_falling_wedge(high_prices, low_prices):
    if (high_prices[0] <= high_prices[1] <= high_prices[2] and
        low_prices[0] <= low_prices[1] <= low_prices[2] and
        high_prices[0] <= high_prices[3] and
        high_prices[1] <= high_prices[4] and
        high_prices[2] <= high_prices[5] and
        low_prices[0] <= low_prices[3] and
        low_prices[1] <= low_prices[4] and
        low_prices[2] <= low_prices[5]):
        return True
    else:
        return False

def scan_interval(interval, limit):
    passing_symbols = []
    symbol_pairs = ['10000000-AIDOGE-USDT', '10000-LADY-USDT', '10000-SATS-USDT', '1000-BONK-USDT', '1000-PEPE-USDT', '1INCH-USDT', 'AAVE-USDT', 'ACE-USDT', 'ACH-USDT', 'ADA-USDT', 'AEVO-USDT', 'AGIX-USDT', 'AGLD-USDT', 'ALGO-USDT', 'ALT-USDT', 'AMB-USDT', 'ANKR-USDT', 'APE-USDT', 'API3-USDT', 'APT-USDT', 'ARB-USDT', 'ARK-USDT', 'ARPA-USDT', 'ASTR-USDT', 'ATA-USDT', 'ATOM-USDT', 'AUCTION-USDT', 'AVAX-USDT', 'AXS-USDT', 'BADGER-USDT', 'BAKE-USDT', 'BAT-USDT', 'BB-USDT', 'BCH-USDT', 'BEAM-USDT', 'BIGTIME-USDT', 'BLUR-USDT', 'BLZ-USDT', 'BNB-USDT', 'BNT-USDT', 'BNX-USDT', 'BOME-USDT', 'BOND-USDT', 'BSV-USDT', 'BTC-USDT', 'CAKE-USDT', 'CELO-USDT', 'CELR-USDT', 'CFX-USDT', 'CHR-USDT', 'CHZ-USDT', 'CKB-USDT', 'COMBO-USDT', 'COMP-USDT', 'CORE-USDT', 'COTI-USDT', 'CRV-USDT', 'CTC-USDT', 'CYBER-USDT', 'DAR-USDT', 'DEGEN-USDT', 'DOGE-USDT', 'DOT-USDT', 'DUSK-USDT', 'DYDX-USDT', 'DYM-USDT', 'EDU-USDT', 'EGLD-USDT', 'ENA-USDT', 'ENJ-USDT', 'ENS-USDT', 'EOS-USDT', 'ETC-USDT', 'ETHFI-USDT', 'ETH-USDT', 'ETHW-USDT', 'FET-USDT', 'FIL-USDT', 'FLM-USDT', 'FL
    for symbol_pair in symbol_pairs:
        high_prices, low_prices = get_indicator_values(symbol_pair, interval, limit)
        if len(high_prices) >= limit and len(low_prices) >= limit:
            passes_filter = filter_falling_wedge(high_prices, low_prices)
            if passes_filter:
                passing_symbols.append(symbol_pair)
    return passing_symbols

def get_coin_overview(symbol):
    # Fetch additional information about the coin using its symbol
    # You can use any relevant API or data source to fetch this information
    # For demonstration purposes, let's just print the symbol
    print("Overview for coin:", symbol)

# Scan Falling Wedge Pattern for different intervals
passing_symbols_5min = scan_interval('5m', 12)  # 12 intervals for 1 hour
passing_symbols_15min = scan_interval('15m', 12)  # 12 intervals for 3 hours
passing_symbols_1hour = scan_interval('1h', 12)  # 12 intervals for 12 hours

# Print the passing symbols for each interval
print("Passing symbols for Falling Wedge Pattern (5-minute interval):", passing_symbols_5min)
print("Passing symbols for Falling Wedge Pattern (15-minute interval):", passing_symbols_15min)
print("Passing symbols for Falling Wedge Pattern (1-hour interval):", passing_symbols_1hour)

# Find the coin that appears in all intervals
common_coins = set(passing_symbols_5min) & set(passing_symbols_15min) & set(passing_symbols_1hour)

# Print the overview of the common coin
if common_coins:
    print("Common coin(s) in all intervals:", common_coins)
    for coin in common_coins:
        get_coin_overview(coin)
else:
    print("No common coin found in all intervals.")
# Out:
# Passing symbols for Falling Wedge Pattern (5-minute interval): ['ARK-USDT', 'CKB-USDT', 'HOT-USDT', 'LPT-USDT', 'NFP-USDT', 'ORDI-USDT', 'PEOPLE-USDT', 'PORTAL-USDT', 'RON-USDT']
# Passing symbols for Falling Wedge Pattern (15-minute interval): ['BCH-USDT', 'FRONT-USDT', 'HBAR-USDT', 'SEI-USDT', 'STORJ-USDT']
# Passing symbols for Falling Wedge Pattern (1-hour interval): ['PEOPLE-USDT']
# No common coin found in all intervals.

# %% [markdown]
# # Rising Wedge

# %%
import requests

def get_indicator_values(symbol, interval, limit):
    url = "https://open-api.bingx.com/openApi/spot/v2/market/kline"
    params = {
        'symbol': symbol,
        'interval': interval,
        'limit': limit
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        if 'data' in data and isinstance(data['data'], list):
            klines = data['data']
            if len(klines) >= limit:
                high_prices = [float(kline[2]) for kline in klines]
                low_prices = [float(kline[3]) for kline in klines]
                return high_prices, low_prices
    return [], []

def filter_rising_wedge(high_prices, low_prices):
    if (high_prices[0] >= high_prices[1] >= high_prices[2] and
        high_prices[3] >= high_prices[1] and
        high_prices[4] >= high_prices[2] and
        low_prices[0] >= low_prices[1] >= low_prices[2] and
        low_prices[3] >= low_prices[1] and
        low_prices[4] >= low_prices[2]):
        return True
    else:
        return False

def scan_interval(interval, limit):
    passing_symbols = []
DT', 'OMNINETWORK-USDT', 'OM-USDT', 'ONDO-USDT', 'ONE-USDT', 'ONG-USDT', 'ONT-USDT', 'OP-USDT', 'ORBS-USDT', 'ORDI-USDT', 'OSMO-USDT', 'OXT-USDT', 'PENDLE-USDT', 'PEOPLE-USDT', 'PERP-USDT', 'PHB-USDT', 'PIXEL-USDT', 'POLYX-USDT', 'PORTAL-USDT', 'POWR-USDT', 'PYTH-USDT', 'QNT-USDT', 'RATS-USDT', 'REEF-USDT', 'REN-USDT', 'REZ-USDT', 'RIF-USDT', 'RLC-USDT', 'RNDR-USDT', 'RON-USDT', 'ROSE-USDT', 'RUNE-USDT', 'RVN-USDT', 'SAGA-USDT', 'SAND-USDT', 'SEI-USDT', 'SFP-USDT', 'SHIB-USDT', 'SKL-USDT', 'SLEEPLESSAI-USDT', 'SLERF-USDT', 'SLP-USDT', 'SNX-USDT', 'SOL-USDT', 'SSV-USDT', 'STARL-USDT', 'STG-USDT', 'STMX-USDT', 'STORJ-USDT', 'STRK-USDT', 'STX-USDT', 'SUI-USDT', 'SUPER-USDT', 'SUSHI-USDT', 'SXP-USDT', 'TAO-USDT', 'THETA-USDT', 'TIA-USDT', 'TLM-USDT', 'TNSR-USDT', 'TOKEN-USDT', 'TONCOIN-USDT', 'TRB-USDT', 'TRU-USDT', 'TRX-USDT', 'TWT-USDT', 'UMA-USDT', 'UNFI-USDT', 'UNI-USDT', 'UST-USDT', 'VANRY-USDT', 'VET-USDT', 'VGX-USDT', 'WAVES-USDT', 'WAXP-USDT', 'WIF-USDT', 'WLD-USDT', 'WOO-USDT', 'W-USDT', 'XAI-USDT', 'XLM-USDT', 'XRP-USDT', 'YFI-USDT', 'YGG-USDT', 'ZEROLEND-USDT', 'ZETA-USDT', 'ZEUS-USDT', 'ZIL-USDT', 'ZRX-USDT']

    for symbol_pair in symbol_pairs:
        high_prices, low_prices = get_indicator_values(symbol_pair, interval, limit)
        if len(high_prices) >= limit and len(low_prices) >= limit:
            passes_filter = filter_rising_wedge(high_prices, low_prices)
            if passes_filter:
                passing_symbols.append(symbol_pair)
    return passing_symbols

def get_coin_overview(symbol):
    # Fetch additional information about the coin using its symbol
    # You can use any relevant API or data source to fetch this information
    # For demonstration purposes, let's just print the symbol
    print("Overview for coin:", symbol)

# Scan Rising Wedge Pattern for different intervals
passing_symbols_5min = scan_interval('5m', 12)  # 12 intervals for 1 hour
passing_symbols_15min = scan_interval('15m', 12)  # 12 intervals for 3 hours
passing_symbols_1hour = scan_interval('1h', 12)  # 12 intervals for 12 hours

# Print the passing symbols for each interval
print("Passing symbols for Rising Wedge Pattern (5-minute interval):", passing_symbols_5min)
print("Passing symbols for Rising Wedge Pattern (15-minute interval):", passing_symbols_15min)
print("Passing symbols for Rising Wedge Pattern (1-hour interval):", passing_symbols_1hour)

# Find the coin that appears in all intervals
common_coins = set(passing_symbols_5min) & set(passing_symbols_15min) & set(passing_symbols_1hour)

# Print the overview of the common coin
if common_coins:
    print("Common coin(s) in all intervals:", common_coins)
    for coin in common_coins:
        get_coin_overview(coin)
else:
    print("No common coin found in all intervals.")
